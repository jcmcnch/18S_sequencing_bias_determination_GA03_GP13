# %%
?abline()
d <- read.csv("ratios.for.histogram.tsv", sep='\t', header = TRUE)
ratios <- d[,2]
hist(ratios, xlab = "GA03 + GP13 Bias (MG:tag)",col = "blue",border = "blue", breaks = 60)
abline(v=median(ratios))
# Out:
# Plot with title “Histogram of ratios”
